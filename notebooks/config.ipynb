# %% [markdown]
# # Project Configuration
#
# Notebook view of the ARIMA forecasting configuration in `src/config.py`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

import config

print("Raw data file:", config.RAW_DATA_FILE)
print("Model file:", config.MODEL_FILE)
print("Forecast file:", config.FORECAST_FILE)
print("ARIMA order:", config.ARIMA_ORDER)
print("Forecast weeks:", config.FORECAST_WEEKS)
